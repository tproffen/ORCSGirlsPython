# %% [markdown]
# <img src="https://github.com/tproffen/ORCSGirlsPython/blob/master/MachineLearning/Images/PoweredTechGirlz.png?raw=1" width="15%" align="right" hpsace="50">
#
# # Activity 2: Bubble Sort
#
# Here are the solutions to the Bubble sort activity. Did you get it right?

# %%
# !mkdir -p Helpers
# !curl -o Helpers/helpers.py https://raw.githubusercontent.com/tproffen/ORCSGirlsPython/master/Algoritms/Helpers/helpers.py

# %%
# %matplotlib inline
import numpy as np
from Helpers.helpers import *

# %% [markdown]
# #### Data

# %%
data=[2,5,7,11,2,1,4,8,12,3,7]

# %%
print (data)
# Out:
# [1, 2, 2, 3, 4, 5, 7, 7, 8, 11, 12]

# %%
n=len(data)
print (n)
# Out:
# 11

# %%
for j in range(n):
  for i in range(n-1):
    if data[i]>data[i+1]:
      temp = data[i]
      data[i] = data[i+1]
      data[i+1] = temp
    updateGraph(i,data)

# %%
print (data)
# Out:
# [1, 2, 2, 3, 4, 5, 7, 7, 8, 11, 12]

# %%
data=[2,5,7,11,2,1,4,8,12,3,7]

# %%
swap=True

for j in range(n):
  if (swap):
    swap=False
    for i in range(n-1):
      if data[i]>data[i+1]:
        temp = data[i]
        data[i] = data[i+1]
        data[i+1] = temp
        swap=True
      updateGraph(i,data)
